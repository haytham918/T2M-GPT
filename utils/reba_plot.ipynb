# %% [markdown]
# ![Reference REBA Assessment](https://ergo-plus.com/wp-content/uploads/rapid-entire-body-assessment-reba-1.png?x73443)

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import reba

# %%
# Generate sample angles
angles = torch.linspace(-180, 180, steps=100)

# Calculate neck angle scores
neck_scores = reba.get_neck_score(angles, steepness=1)

# Plot the graph
plt.plot(angles.numpy(), neck_scores.numpy(), label='Neck Angle Score')
plt.xlabel('Neck Angle (degrees)')
plt.ylabel('REBA Score')
plt.yticks([1, 2, 3, 4])
plt.title('Neck Angle Score Graph')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Generate sample angles
angles = torch.linspace(-180, 180, steps=100)

# Calculate trunk angle scores
trunk_scores = reba.get_trunk_score(angles, steepness=1)

# Plot the graph
plt.plot(angles.numpy(), trunk_scores.numpy(), label='Trunk Angle Score')
plt.xlabel('Trunk Angle (degrees)')
plt.ylabel('REBA Score')
plt.title('Trunk Angle Score Graph')
plt.yticks([1, 2, 3, 4])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Generate sample angles
angles = torch.linspace(-180, 180, steps=100)

# Calculate leg angle scores
leg_scores = reba.get_leg_score(angles, steepness=1)

# Plot the graph
plt.plot(angles.numpy(), leg_scores.numpy(), label='Leg Angle Score')
plt.xlabel('Leg Angle (degrees)')
plt.ylabel('REBA Score')
plt.title('Leg Angle Score Graph')
plt.yticks([1, 2, 3, 4])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Generate sample angles
angles = torch.linspace(-180, 180, steps=100)

# Calculate upper arm angle scores
upper_arm_scores = reba.get_upper_arm_score(angles, steepness=1)

# Plot the graph
plt.plot(angles.numpy(), upper_arm_scores.numpy(), label='Upper Arm Angle Score')
plt.xlabel('Upper Arm Angle (degrees)')
plt.ylabel('REBA Score')
plt.title('Upper Arm Angle Score Graph')
plt.yticks([1, 2, 3, 4])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Generate sample angles
angles = torch.linspace(-180, 180, steps=100)

# Calculate lower arm angle scores
lower_arm_scores = reba.get_lower_arm_score(angles, steepness=1)

# Plot the graph
plt.plot(angles.numpy(), lower_arm_scores.numpy(), label='Lower Arm Angle Score')
plt.xlabel('Lower Arm Angle (degrees)')
plt.ylabel('REBA Score')
plt.title('Lower Arm Angle Score Graph')
plt.yticks([1, 2, 3, 4])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Generate sample angles
angles = torch.linspace(-180, 180, steps=100)

# Calculate wrist angle scores
wrist_scores = reba.get_wrist_score(angles, steepness=1)

# Plot the graph
plt.plot(angles.numpy(), wrist_scores.numpy(), label='Wrist Angle Score')
plt.xlabel('Wrist Angle (degrees)')
plt.ylabel('REBA Score')
plt.title('Wrist Angle Score Graph')
plt.yticks([1, 2, 3, 4])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Example input values with requires_grad=True to enable gradient tracking
neck = torch.tensor([1.2], requires_grad=True)  # Neck value between 1 and 2
leg = torch.tensor([3.0], requires_grad=True)   # Leg value in category 3
trunk = torch.tensor([3.8], requires_grad=True) # Trunk value between 4 and 5

# Calculate Score A
score = reba.get_score_a(neck, leg, trunk)

# Perform backward pass to compute gradients
score.backward()

# Print gradients
print("Gradient w.r.t Neck:", neck.grad)
print("Gradient w.r.t Leg:", leg.grad)
print("Gradient w.r.t Trunk:", trunk.grad)

reba.plot_score_a_3d(neck_value=1.0, gamma=10.0)
# NOTE: All scores were manually verified using the REBA table A.
# Out:
# Gradient w.r.t Neck: tensor([0.0493])
# Gradient w.r.t Leg: tensor([0.0018])
# Gradient w.r.t Trunk: tensor([0.0493])
# Table 1: tensor([1., 1., 1.]) -> Score: 1.00 | Predicted Score: 1.00
# Table 2: tensor([1., 1., 2.]) -> Score: 2.00 | Predicted Score: 2.00
# Table 3: tensor([1., 1., 3.]) -> Score: 2.00 | Predicted Score: 2.00
# Table 4: tensor([1., 1., 4.]) -> Score: 3.00 | Predicted Score: 3.00
# Table 5: tensor([1., 1., 5.]) -> Score: 4.00 | Predicted Score: 4.00
# Table 6: tensor([1., 2., 1.]) -> Score: 2.00 | Predicted Score: 2.00
# Table 7: tensor([1., 2., 2.]) -> Score: 3.00 | Predicted Score: 3.00
# Table 8: tensor([1., 2., 3.]) -> Score: 4.00 | Predicted Score: 4.00
# Table 9: tensor([1., 2., 4.]) -> Score: 5.00 | Predicted Score: 5.00
# Table 10: tensor([1., 2., 5.]) -> Score: 6.00 | Predicted Score: 6.00
# Table 11: tensor([1., 3., 1.]) -> Score: 3.00 | Predicted Score: 3.00
# Table 12: tensor([1., 3., 2.]) -> Score: 4.00 | Predicted Score: 4.00
# ...

# %%
# Example input values with requires_grad=True to enable gradient tracking
upper_arm = torch.tensor([4.1], requires_grad=True)  # Upper Arm value between 1 and 6
lower_arm = torch.tensor([1.5], requires_grad=True)   # Lower Arm value between 1 and 2
wrist = torch.tensor([2.8], requires_grad=True) # Wrist value between 1 and 3

# Calculate Score B
score = reba.get_score_b(upper_arm, lower_arm, wrist)

# Perform backward pass to compute gradients
score.backward()

# Print gradients
print("Gradient w.r.t Upper Arm:", upper_arm.grad)
print("Gradient w.r.t Lower Arm:", lower_arm.grad)
print("Gradient w.r.t Wrist:", wrist.grad)

reba.plot_score_b_3d(lower_arm_value=1.0, gamma=10.0)
# NOTE: All scores were manually verified using the REBA table B.
# Out:
# Gradient w.r.t Upper Arm: tensor([0.0135])
# Gradient w.r.t Lower Arm: tensor([9.9842])
# Gradient w.r.t Wrist: tensor([0.0247])
# Table 1: tensor([1., 1., 1.]) -> Score: 1.00 | Predicted Score: 1.00
# Table 2: tensor([1., 1., 2.]) -> Score: 1.00 | Predicted Score: 1.00
# Table 3: tensor([1., 1., 3.]) -> Score: 3.00 | Predicted Score: 3.00
# Table 4: tensor([1., 1., 4.]) -> Score: 4.00 | Predicted Score: 4.00
# Table 5: tensor([1., 1., 5.]) -> Score: 6.00 | Predicted Score: 6.00
# Table 6: tensor([1., 1., 6.]) -> Score: 7.00 | Predicted Score: 7.00
# Table 7: tensor([1., 2., 1.]) -> Score: 2.00 | Predicted Score: 2.00
# Table 8: tensor([1., 2., 2.]) -> Score: 2.00 | Predicted Score: 2.00
# Table 9: tensor([1., 2., 3.]) -> Score: 4.00 | Predicted Score: 4.00
# Table 10: tensor([1., 2., 4.]) -> Score: 5.00 | Predicted Score: 5.00
# Table 11: tensor([1., 2., 5.]) -> Score: 7.00 | Predicted Score: 7.00
# Table 12: tensor([1., 2., 6.]) -> Score: 8.00 | Predicted Score: 8.00
# ...

# %%
# Example input values with requires_grad=True to enable gradient tracking
score_a = torch.tensor([8.1], requires_grad=True)  # Score A value between 1 and 12
score_b = torch.tensor([6.5], requires_grad=True)   # Score B value between 1 and 12

# Calculate Score C
score = reba.get_score_c(score_a, score_b)

# Perform backward pass to compute gradients
score.backward()

# Print gradients
print("Gradient w.r.t Score A:", score_a.grad)
print("Gradient w.r.t Score B:", score_b.grad)

reba.plot_score_c_3d(gamma=10.0)
# NOTE: All scores were manually verified using the REBA table C.
# Out:
# Gradient w.r.t Score A: tensor([0.0035])
# Gradient w.r.t Score B: tensor([0.0017])
# Table 1: tensor([1., 1.]) -> Score: 1.00 | Predicted Score: 1.00
# Table 2: tensor([1., 2.]) -> Score: 1.00 | Predicted Score: 1.00
# Table 3: tensor([1., 3.]) -> Score: 1.00 | Predicted Score: 1.00
# Table 4: tensor([1., 4.]) -> Score: 2.00 | Predicted Score: 2.00
# Table 5: tensor([1., 5.]) -> Score: 3.00 | Predicted Score: 3.00
# Table 6: tensor([1., 6.]) -> Score: 3.00 | Predicted Score: 3.00
# Table 7: tensor([1., 7.]) -> Score: 4.00 | Predicted Score: 4.00
# Table 8: tensor([1., 8.]) -> Score: 5.00 | Predicted Score: 5.00
# Table 9: tensor([1., 9.]) -> Score: 6.00 | Predicted Score: 6.00
# Table 10: tensor([ 1., 10.]) -> Score: 7.00 | Predicted Score: 7.00
# Table 11: tensor([ 1., 11.]) -> Score: 7.00 | Predicted Score: 7.00
# Table 12: tensor([ 1., 12.]) -> Score: 7.00 | Predicted Score: 7.00
# Table 13: tensor([2., 1.]) -> Score: 1.00 | Predicted Score: 1.00
# ...

# %%
# Example input values with requires_grad=True to enable gradient tracking
score_c = torch.tensor([8.1], requires_grad=True)  # Score A value between 1 and 16

# Calculate REBA action level
score = reba.get_action_level(score_c)

# Perform backward pass to compute gradients
score.backward()

# Print gradients
print("Gradient w.r.t Score C:", score_c.grad)

reba.plot_action_level(gamma=10.0)
# NOTE: All scores were manually verified using the REBA table C.
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 5
#       2 score_c = torch.tensor([8.1], requires_grad=True)  # Score A value between 1 and 16
#       4 # Calculate REBA action level
# ----> 5 score = reba.get_action_level(score_c)
#       7 # Perform backward pass to compute gradients
#       8 score.backward()
#
# File ~/Developer/T2M-GPT/utils/reba.py:500, in get_action_level(score, gamma)
#     497 inputs = torch.stack([score], dim=-1)  # Shape: (batch_size, 1)
#     499 # Compute RBF distances
# --> 500 distances = torch.cdist(inputs, coordinates.unsqueeze(0), p=2)  # Shape: (batch_size, N)
#     501 weights = torch.exp(-gamma * distances ** 2)  # RBF weights (Gaussian kernel)
#     503 # Normalize weights
#
# File /opt/miniconda3/envs/T2M-GPT/lib/python3.9/site-packages/torch/functional.py:1478, in cdist(x1, x2, p, compute_mode)
# ...
